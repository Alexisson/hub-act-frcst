# %%
from loans_predict import LoansPredict, PredictEnum
from predictor import PredictInput

# %%
predictor = LoansPredict(PredictEnum.MSP_NEW_LOANS)

# %%
predictor.regions
# Out:
# {22: 'Российская Федерация',
#  23: 'Центральный федеральный округ',
#  24: 'Белгородская область',
#  25: 'Брянская область',
#  26: 'Владимирская область',
#  27: 'Воронежская область',
#  28: 'Ивановская область',
#  29: 'Калужская область',
#  30: 'Костромская область',
#  31: 'Курская область',
#  32: 'Липецкая область',
#  33: 'Московская область',
#  34: 'Орловская область',
#  35: 'Рязанская область',
#  36: 'Смоленская область',
#  37: 'Тамбовская область',
#  38: 'Тверская область',
#  39: 'Тульская область',
#  40: 'Ярославская область',
#  41: 'г. Москва',
#  42: 'Северо-Западный федеральный округ',
#  43: 'Республика Карелия',
#  44: 'Республика Коми',
#  45: 'Архангельская область',
#  46: 'Архангельская область, в том числе Ненецкий автономный округ',
#  47: 'Архангельская область без данных по Ненецкому автономному округу',
#  48: 'Вологодская область',
#  49: 'Калининградская область',
#  50: 'Ленинградская область',
#  51: 'Мурманская область',
# ...

# %%
predictor.get_regions_predict([23], PredictInput(start_date='2023-06', custom=True, season_ord=(1, 1, 0, 12),
                                                     custom_pdq=(1, 0, 2), trend='ct'))
# Out:
# [('Центральный федеральный округ',
#   PredictResult(predict=2023-06-01    537435.088182
#   2023-07-01    493553.038063
#   2023-08-01    486889.670514
#   2023-09-01    563954.813598
#   2023-10-01    533272.290082
#   2023-11-01    518977.243249
#   2023-12-01    727897.389023
#   2024-01-01    451680.905980
#   2024-02-01    491747.134908
#   2024-03-01    522374.750791
#   2024-04-01    540634.703825
#   2024-05-01    539119.553565
#   2024-06-01    603384.357844
#   2024-07-01    603865.739507
#   2024-08-01    594521.528187
#   2024-09-01    682681.547438
#   2024-10-01    626204.464155
#   2024-11-01    619095.757480
#   2024-12-01    834495.478294
#   2025-01-01    536146.085034
#   2025-02-01    587114.065978
#   2025-03-01    658112.440916
#   2025-04-01    677763.703272
#   2025-05-01    699663.722553
#   2025-06-01    750989.475475
#   2025-07-01    732452.707684
#   2025-08-01    726522.941151
#   2025-09-01    811528.590343
#   2025-10-01    769487.497110
# ...

# %%
predictor.show_regions_plot([23], PredictInput(start_date='2023-06', custom=True, season_ord=(1, 1, 0, 12),
                                                     custom_pdq=(1, 0, 2), trend='ct'))

# %%
predictor.get_regions_predict([42], PredictInput(start_date='2023-06', trend='ct'))
# Out:
# [('Северо-Западный федеральный округ',
#   PredictResult(predict=2023-06-01    529780.811498
#   2023-07-01    491368.524770
#   2023-08-01    471223.038340
#   2023-09-01    564416.212681
#   2023-10-01    458900.071085
#   2023-11-01    520603.362669
#   2023-12-01    717737.640777
#   2024-01-01    453822.148960
#   2024-02-01    483953.214236
#   2024-03-01    517419.538144
#   2024-04-01    528764.147615
#   2024-05-01    530448.324910
#   2024-06-01    587171.327248
#   2024-07-01    597279.127501
#   2024-08-01    576733.880875
#   2024-09-01    676936.814308
#   2024-10-01    513192.937904
#   2024-11-01    612054.779901
#   2024-12-01    819218.502172
#   2025-01-01    527738.658482
#   2025-02-01    572188.440174
#   2025-03-01    648382.786470
#   2025-04-01    662911.609495
#   2025-05-01    688855.468756
#   2025-06-01    730425.324689
#   2025-07-01    719198.704591
#   2025-08-01    699942.733116
#   2025-09-01    799483.604012
#   2025-10-01    666357.196765
# ...

# %%
predictor.show_regions_plot([42], PredictInput(start_date='2023-06', trend='ct'))

# %%
predictor.get_regions_predict([95], PredictInput(start_date='2023-06', trend='n'))
# Out:
# [('Сибирский федеральный округ',
#   PredictResult(predict=2023-06-01    497506.198784
#   2023-07-01    440764.173340
#   2023-08-01    442169.081866
#   2023-09-01    516001.911615
#   2023-10-01    492453.674386
#   2023-11-01    474381.058076
#   2023-12-01    679537.893387
#   2024-01-01    408494.471808
#   2024-02-01    443284.083465
#   2024-03-01    459330.043936
#   2024-04-01    475292.332609
#   2024-05-01    464533.498229
#   2024-06-01    512988.895893
#   2024-07-01    511798.050057
#   2024-08-01    503157.392209
#   2024-09-01    588990.115396
#   2024-10-01    529320.039155
#   2024-11-01    519050.354736
#   2024-12-01    731189.341842
#   2025-01-01    429312.192456
#   2025-02-01    477001.184511
#   2025-03-01    544950.049821
#   2025-04-01    561237.565781
#   2025-05-01    579949.043538
#   2025-06-01    597754.458440
#   2025-07-01    566014.086590
#   2025-08-01    562805.636748
#   2025-09-01    641978.075765
#   2025-10-01    602043.910598
# ...

# %%
predictor.show_regions_plot([95], PredictInput(start_date='2023-06', trend='n'))

# %%
predictor.get_regions_predict([55, 64, 72, 87, 106], PredictInput(start_date='2023-06', trend='ct'))
# Out:
# [('Южный федеральный округ',
#   PredictResult(predict=2023-06-01    530123.168318
#   2023-07-01    482522.877308
#   2023-08-01    475914.454672
#   2023-09-01    553318.842996
#   2023-10-01    524614.840711
#   2023-11-01    509608.062337
#   2023-12-01    717717.058305
#   2024-01-01    442637.924594
#   2024-02-01    481501.016599
#   2024-03-01    508849.197228
#   2024-04-01    526560.719120
#   2024-05-01    522950.780709
#   2024-06-01    583961.937752
#   2024-07-01    583438.688457
#   2024-08-01    573429.877750
#   2024-09-01    661530.287498
#   2024-10-01    604591.042134
#   2024-11-01    596758.903623
#   2024-12-01    811361.123654
#   2025-01-01    512245.401158
#   2025-02-01    562364.989186
#   2025-03-01    632447.630303
#   2025-04-01    651264.435871
#   2025-05-01    672282.398704
#   2025-06-01    717318.967726
#   2025-07-01    695201.316242
#   2025-08-01    688472.924216
#   2025-09-01    772907.169541
#   2025-10-01    731486.734795
# ...

# %%
predictor.show_regions_plot([55], PredictInput(start_date='2023-05', trend='ct'))
predictor.show_regions_plot([64], PredictInput(start_date='2023-05', trend='ct'))
predictor.show_regions_plot([72], PredictInput(start_date='2023-05', trend='ct'))
predictor.show_regions_plot([87], PredictInput(start_date='2023-05', trend='ct'))
predictor.show_regions_plot([106], PredictInput(start_date='2023-05', trend='ct'))

# %%
predictor.get_regions_predict([22], PredictInput(start_date='2023-05', custom=True, season_ord=(1, 1, 1, 12),
                                                     custom_pdq=(1, 1, 1), trend='ct'))
# Out:
# [('Российская Федерация',
#   PredictResult(predict=2023-05-01    401772.619071
#   2023-06-01    528831.992007
#   2023-07-01    483752.784129
#   2023-08-01    482589.925630
#   2023-09-01    557828.318170
#   2023-10-01    528111.388926
#   2023-11-01    517932.925775
#   2023-12-01    719543.896271
#   2024-01-01    448972.859622
#   2024-02-01    490608.220766
#   2024-03-01    525019.518192
#   2024-04-01    543746.624479
#   2024-05-01    488023.536722
#   2024-06-01    603493.502432
#   2024-07-01    593275.587638
#   2024-08-01    586960.928369
#   2024-09-01    670623.668058
#   2024-10-01    618923.305349
#   2024-11-01    611570.923937
#   2024-12-01    819636.926169
#   2025-01-01    527836.933482
#   2025-02-01    575823.817935
#   2025-03-01    638966.587483
#   2025-04-01    656675.063276
#   2025-05-01    598994.689411
#   2025-06-01    718336.913859
#   2025-07-01    694319.711532
#   2025-08-01    689192.737988
#   2025-09-01    768788.770701
# ...

# %%
predictor.show_regions_plot([22], PredictInput(start_date='2023-05', custom=True, season_ord=(1, 1, 1, 12),
                                                     custom_pdq=(1, 1, 1), trend='ct'))

# %%
predictor_msp_loans_volume = LoansPredict(PredictEnum.MSP_LOANS_VOLUME)

# %%
predictor_msp_loans_volume.get_regions_predict([23, 42, 55, 64, 72, 87, 95, 106], PredictInput(trend = 'ct'))
# Out:
# [('Центральный федеральный округ',
#   PredictResult(predict=2023-05-01    5.044569e+06
#   2023-06-01    5.131885e+06
#   2023-07-01    4.806854e+06
#   2023-08-01    5.067086e+06
#   2023-09-01    5.318043e+06
#   2023-10-01    5.425869e+06
#   2023-11-01    5.633609e+06
#   2023-12-01    5.890985e+06
#   2024-01-01    5.931387e+06
#   2024-02-01    6.259793e+06
#   2024-03-01    6.414810e+06
#   2024-04-01    6.654026e+06
#   2024-05-01    6.849630e+06
#   2024-06-01    6.984319e+06
#   2024-07-01    6.706822e+06
#   2024-08-01    7.014753e+06
#   2024-09-01    7.313569e+06
#   2024-10-01    7.469418e+06
#   2024-11-01    7.725343e+06
#   2024-12-01    8.031065e+06
#   2025-01-01    8.119977e+06
#   2025-02-01    8.497055e+06
#   2025-03-01    8.700906e+06
#   2025-04-01    8.989119e+06
#   2025-05-01    9.233882e+06
#   2025-06-01    9.417892e+06
#   2025-07-01    9.189880e+06
#   2025-08-01    9.547456e+06
#   2025-09-01    9.896081e+06
#   2025-10-01    1.010190e+07
# ...

# %%
predictor_msp_loans_volume.show_regions_plot([23], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([42], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([55], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([64], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([72], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([87], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([95], PredictInput(trend = 'ct'))
predictor_msp_loans_volume.show_regions_plot([106], PredictInput(trend = 'ct'))

# %%
predictor_msp_loans_volume.get_regions_predict([22], PredictInput(trend = 'ct', custom = True,
season_ord = (1,1,1,12), custom_pdq = (1,1,1)))
# Out:
# [('Российская Федерация',
#   PredictResult(predict=2023-05-01    1.089059e+07
#   2023-06-01    1.111363e+07
#   2023-07-01    1.053189e+07
#   2023-08-01    1.095011e+07
#   2023-09-01    1.135915e+07
#   2023-10-01    1.171634e+07
#   2023-11-01    1.202710e+07
#   2023-12-01    1.236511e+07
#   2024-01-01    1.248977e+07
#   2024-02-01    1.275602e+07
#   2024-03-01    1.320128e+07
#   2024-04-01    1.366395e+07
#   2024-05-01    1.388577e+07
#   2024-06-01    1.414289e+07
#   2024-07-01    1.358085e+07
#   2024-08-01    1.402204e+07
#   2024-09-01    1.445986e+07
#   2024-10-01    1.484781e+07
#   2024-11-01    1.519390e+07
#   2024-12-01    1.556204e+07
#   2025-01-01    1.563372e+07
#   2025-02-01    1.593147e+07
#   2025-03-01    1.640416e+07
#   2025-04-01    1.689047e+07
#   2025-05-01    1.713684e+07
#   2025-06-01    1.741507e+07
#   2025-07-01    1.688705e+07
#   2025-08-01    1.735790e+07
#   2025-09-01    1.781855e+07
#   2025-10-01    1.822623e+07
# ...

# %%
predictor_msp_loans_volume.show_regions_plot([22], PredictInput(trend = 'ct', custom = True,
season_ord = (1,1,1,12),
custom_pdq = (1,1,1)))

# %%
predictor_resident_new_loans = LoansPredict(PredictEnum.RESIDENT_NEW_LOANS)
predictor_resident_new_loans.get_regions_predict([106], PredictInput(trend = 'n',
custom = False))
# Out:
# File downloaded:01_04_A_New_loans_corp_20240501.xlsx
# File downloaded:01_04_A_New_loans_corp_20240401.xlsx
# File downloaded:01_04_A_New_loans_corp_20240301.xlsx
# File downloaded:01_04_A_New_loans_corp_20240201.xlsx
# File downloaded:01_04_A_New_loans_corp_20240101.xlsx
# File downloaded:01_04_A_New_loans_corp_20231201.xlsx
# File downloaded:01_04_A_New_loans_corp_20231101.xlsx
# File downloaded:01_04_A_New_loans_corp_20231001.xlsx
# File downloaded:01_04_A_New_loans_corp_20230901.xlsx
# File downloaded:01_04_A_New_loans_corp_20230801.xlsx
# File downloaded:01_04_A_New_loans_corp_20230701.xlsx
# File downloaded:01_04_A_New_loans_corp_20230601.xlsx
# File downloaded:01_04_A_New_loans_corp_20230501.xlsx
# File downloaded:01_04_A_New_loans_corp_20230401.xlsx
# File downloaded:01_04_A_New_loans_corp_20230301.xlsx
# File downloaded:01_04_A_New_loans_corp_20230201.xlsx
# File downloaded:01_04_A_New_loans_corp_20230101.xlsx
# File downloaded:01_04_A_New_loans_corp_20221201.xlsx
# ...

# %%
predictor_resident_new_loans.show_regions_plot([106], PredictInput(trend = 'n',
custom = False))

# %%
predictor_resident_new_loans.get_regions_predict([72], PredictInput(trend = 'ct',
custom = False))
# Out:
# [('Приволжский федеральный округ',
#   PredictResult(predict=2023-05-01    158326.180636
#   2023-06-01    145096.380160
#   2023-07-01    203313.488445
#   2023-08-01    203008.676822
#   2023-09-01    170519.353718
#   2023-10-01    209379.145808
#   2023-11-01    236010.750048
#   2023-12-01    175798.456163
#   2024-01-01    410511.340170
#   2024-02-01    163595.047026
#   2024-03-01    152316.150715
#   2024-04-01    205387.663502
#   2024-05-01    180952.905015
#   2024-06-01    167769.021055
#   2024-07-01    226032.045857
#   2024-08-01    225773.150751
#   2024-09-01    193329.744164
#   2024-10-01    232235.452771
#   2024-11-01    258912.973527
#   2024-12-01    198746.596159
#   2025-01-01    433505.396683
#   2025-02-01    186635.020056
#   2025-03-01    175402.040262
#   2025-04-01    228519.469565
#   2025-05-01    204130.627595
#   2025-06-01    190992.660152
#   2025-07-01    249301.601471
#   2025-08-01    249088.622881
#   2025-09-01    216691.132811
# ...

# %%
predictor_resident_new_loans.show_regions_plot([72], PredictInput(trend = 'ct',
custom = False))

# %%
predictor_resident_new_loans.get_regions_predict([23, 42, 55, 64,  87, 95], PredictInput(trend = 'n',
custom = False, start_date='2023-07'))

# %%
#predictor_resident_new_loans.show_regions_plot([23, 42, 55, 64,  87, 95], PredictInput(trend = 'n',
#custom = False, start_date='2023-07'))

# %%
predictor_resident_new_loans.get_regions_predict([22], PredictInput(trend = 'n',
custom = True, start_date='2023-07', season_ord = (1,1,1,12),
custom_pdq = (0,1,0)))
# Out:
# [('Российская Федерация',
#   PredictResult(predict=2023-07-01    243922.644307
#   2023-08-01    292998.181003
#   2023-09-01    203702.285189
#   2023-10-01    253584.541485
#   2023-11-01    260623.977652
#   2023-12-01    212473.859578
#   2024-01-01    398441.886748
#   2024-02-01    187945.818854
#   2024-03-01    207500.650672
#   2024-04-01    206668.573981
#   2024-05-01    210903.243020
#   2024-06-01    214248.408726
#   2024-07-01    276365.283703
#   2024-08-01    264395.192648
#   2024-09-01    236384.268840
#   2024-10-01    284608.008655
#   2024-11-01    317207.281055
#   2024-12-01    243009.075896
#   2025-01-01    495598.362873
#   2025-02-01    235309.428381
#   2025-03-01    215429.720350
#   2025-04-01    277082.664532
#   2025-05-01    286772.211691
#   2025-06-01    269116.141339
#   2025-07-01    330945.955368
#   2025-08-01    365306.895312
#   2025-09-01    290783.288412
#   2025-10-01    340265.771585
#   2025-11-01    353466.217100
# ...

# %%
predictor_resident_new_loans.show_regions_plot([22], PredictInput(trend = 'n',
custom = True, start_date='2023-07', season_ord = (1,1,1,12),
custom_pdq = (0,1,0)))

# %%
predictor_resident_loans_volume = LoansPredict(PredictEnum.RESIDENT_LOANS_VOLUME)
predictor_resident_loans_volume.get_regions_predict([23, 42, 55, 87])
predictor_resident_loans_volume.show_regions_plot([23])
predictor_resident_loans_volume.show_regions_plot([42])
predictor_resident_loans_volume.show_regions_plot([55])
predictor_resident_loans_volume.show_regions_plot([87])

# %%
predictor_resident_loans_volume.get_regions_predict([64, 72, 95, 106], PredictInput(trend='c', start_date='2023-12'))
predictor_resident_loans_volume.show_regions_plot([64], PredictInput(trend='c', start_date='2023-12'))
predictor_resident_loans_volume.show_regions_plot([72], PredictInput(trend='c', start_date='2023-12'))
predictor_resident_loans_volume.show_regions_plot([95], PredictInput(trend='c', start_date='2023-12'))
predictor_resident_loans_volume.show_regions_plot([106], PredictInput(trend='c', start_date='2023-12'))

# %%
predictor_resident_loans_volume.get_regions_predict([22], PredictInput(start_date = '2023-05',
trend = 'n',
custom = True,
season_ord = (1,1,1,12),
custom_pdq = (1,1,1)))
predictor_resident_loans_volume.show_regions_plot([22], PredictInput(start_date = '2023-05',
trend = 'n',
custom = True,
season_ord = (1,1,1,12),
custom_pdq = (1,1,1)))
